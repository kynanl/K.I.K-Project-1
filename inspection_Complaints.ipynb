# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_path = "311_Restaurant_Complaints.csv"
request_data = pd.read_csv(data_path)
data_path2 = "Food_Inspections.csv"
request_data2 =pd.read_csv(data_path2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-fd7d0ab5c733> in <module>
#       1 data_path = "311_Restaurant_Complaints.csv"
# ----> 2 request_data = pd.read_csv(data_path)
#       3 data_path2 = "Food_Inspections.csv"
#       4 request_data2 =pd.read_csv(data_path2)
#
# ...

# %%
request_data.head()

# %%
# split date and time of day
request_data[['COMPLAINT_DATE', 'COMPLAINT_TIME']]= request_data.CREATED_DATE.str.split(" ", expand = True,)
request_data

# %%
#sort values by date
request_data["COMPLAINT_DATE"] = pd.to_datetime(request_data.COMPLAINT_DATE)
complaints = request_data.sort_values('COMPLAINT_DATE')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cf06b7c534b5> in <module>
#       1 #sort values by date
# ----> 2 request_data["COMPLAINT_DATE"] = pd.to_datetime(request_data.COMPLAINT_DATE)
#       3 complaints = request_data.sort_values('COMPLAINT_DATE')
#
# NameError: name 'request_data' is not defined

# %%
#remove columns we will not use 
restuarant_complaints = complaints[["COMPLAINT_DATE","COMPLAINT_TIME", "STATUS", "CLOSED_DATE", "LOCATION", "ZIP_CODE", "LATITUDE", "LONGITUDE"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d5f3f87fd10e> in <module>
#       1 #remove columns we will not use
# ----> 2 restuarant_complaints = complaints[["COMPLAINT_DATE","COMPLAINT_TIME", "STATUS", "CLOSED_DATE", "LOCATION", "ZIP_CODE", "LATITUDE", "LONGITUDE"]]
#
# NameError: name 'complaints' is not defined

# %%
request_data2.rename(columns = {"Location": "LOCATION"})
# Out:
#         Inspection ID                     DBA Name  \
# 0             2177022       CORNERSTONE CHILD CARE
# 1             1561742                      LE CAFE
# 2             2288609  LITTLE PEOPLE LEARNING, INC
# 3              335329                   J & J FISH
# 4             1389412                ROYAL CHICKEN
# ...               ...                          ...
# 208249        2078722                         CRIO
# 208250        2288668       ORIGINAL PANCAKE HOUSE
# 208251        2059313  SUBWAY SANDWICHES AND SALAD
# 208252        1497846                RESIDENCE INN
# 208253        1369996                    ST. AILBE
#
#                            AKA Name  License #  \
# 0            CORNERSTONE CHILD CARE  2215716.0
# 1                           LE CAFE  2178017.0
# 2       LITTLE PEOPLE LEARNING, INC  2570234.0
# 3                        J & J FISH    69148.0
# 4                               NaN  2289533.0
# ...                             ...        ...
# ...

# %%
#separate complaint code from comments
for row in request_data2:
    try:
        request_data2[['Violation_Code', 'Violation_Comment']]= request_data2.Violations.str.split("- Comments:", expand = True,)
    except ValueError:
        print("empty value")
# Out:
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value

# %%
#Check split column
request_data2.int(request_data2["Zip"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b2bbc8b891e5> in <module>
#       1 #Check split column
# ----> 2 request_data2.int(request_data2["Zip"])
#
# NameError: name 'request_data2' is not defined

# %%
#merge inspection  data with complaint data
inspect_complaints = pd.merge(request_data2, restuarant_complaints, on = "LOCATION", how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-58f64d008185> in <module>
# ----> 1 inspect_complaints = pd.merge(request_data2, restuarant_complaints, on = "LOCATION", how = 'inner')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
# ...

# %%
#analyze patterns for complaints
