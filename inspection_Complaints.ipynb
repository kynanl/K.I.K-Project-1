# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_path = "311_Restaurant_Complaints.csv"
request_data = pd.read_csv(data_path)
data_path2 = "Food_Inspections.csv"
request_data2 =pd.read_csv(data_path2)

# %%
request_data.head()
# Out:
#        SR_NUMBER               SR_TYPE SR_SHORT_CODE OWNER_DEPARTMENT  \
# 0  SR18-00217715  Restaurant Complaint           HFB           Health
# 1  SR18-00196003  Restaurant Complaint           HFB           Health
# 2  SR19-00333204  Restaurant Complaint           HFB           Health
# 3  SR19-00334364  Restaurant Complaint           HFB           Health
# 4  SR19-00335464  Restaurant Complaint           HFB           Health
#
#       STATUS      CREATED_DATE LAST_MODIFIED_DATE       CLOSED_DATE  \
# 0  Completed  12/20/2018 15:06    5/16/2019 16:33   1/29/2019 17:19
# 1  Completed   12/19/2018 8:03    2/13/2020 17:44   2/27/2019 17:14
# 2  Completed    9/28/2018 9:27    2/13/2020 19:19  11/20/2018 13:44
# 3  Completed    9/28/2018 8:01    2/13/2020 19:19   10/3/2018 17:20
# 4  Completed   9/27/2018 21:31    2/13/2020 19:20   10/3/2018 17:18
#
#         STREET_ADDRESS     CITY  ... CREATED_HOUR  CREATED_DAY_OF_WEEK  \
# 0    9500 S Kedzie AVE      NaN  ...           15                    5
# 1                  NaN      NaN  ...            8                    4
# 2     109 W MADISON ST  CHICAGO  ...            9                    6
# 3     7900 S PERRY AVE  CHICAGO  ...            8                    6
# 4  1651 W ROOSEVELT RD  CHICAGO  ...           21                    5
#
#    CREATED_MONTH X_COORDINATE Y_COORDINATE   LATITUDE  LONGITUDE  \
# 0             12          NaN          NaN        NaN        NaN
# 1             12          NaN          NaN        NaN        NaN
# 2              9  1175449.109  1900353.864  41.881956 -87.631215
# 3              9  1176908.775  1852545.439  41.750732 -87.627298
# 4              9  1165345.566  1894764.934  41.866840 -87.668474
#
#                                    LOCATION        Date   Time
# 0                                       NaN  12/20/2018  15:06
# 1                                       NaN  12/19/2018   8:03
# 2  (41.881955643397106, -87.63121511544936)   9/28/2018   9:27
# 3   (41.75073223780356, -87.62729770130572)   9/28/2018   8:01
# 4  (41.866839982710786, -87.66847398368179)   9/27/2018  21:31
#
# [5 rows x 39 columns]

# %%
# split date and time of day
request_data[['COMPLAINT_DATE', 'COMPLAINT_TIME']]= request_data.CREATED_DATE.str.split(" ", expand = True,)
request_data
# Out:
#           SR_NUMBER               SR_TYPE SR_SHORT_CODE OWNER_DEPARTMENT  \
# 0     SR18-00217715  Restaurant Complaint           HFB           Health
# 1     SR18-00196003  Restaurant Complaint           HFB           Health
# 2     SR19-00333204  Restaurant Complaint           HFB           Health
# 3     SR19-00334364  Restaurant Complaint           HFB           Health
# 4     SR19-00335464  Restaurant Complaint           HFB           Health
# ...             ...                   ...           ...              ...
# 1971  SR18-00018286  Restaurant Complaint           HFB           Health
# 1972  SR19-01359422  Restaurant Complaint           HFB           Health
# 1973  SR19-03009206  Restaurant Complaint           HFB           Health
# 1974  SR18-00018559  Restaurant Complaint           HFB           Health
# 1975  SR19-02816434  Restaurant Complaint           HFB           Health
#
#          STATUS      CREATED_DATE LAST_MODIFIED_DATE       CLOSED_DATE  \
# 0     Completed  12/20/2018 15:06    5/16/2019 16:33   1/29/2019 17:19
# 1     Completed   12/19/2018 8:03    2/13/2020 17:44   2/27/2019 17:14
# 2     Completed    9/28/2018 9:27    2/13/2020 19:19  11/20/2018 13:44
# 3     Completed    9/28/2018 8:01    2/13/2020 19:19   10/3/2018 17:20
# 4     Completed   9/27/2018 21:31    2/13/2020 19:20   10/3/2018 17:18
# ...         ...               ...                ...               ...
# 1971  Completed   12/1/2018 19:38    2/13/2020 16:54   2/21/2019 11:33
# 1972  Completed    4/20/2019 9:24    2/13/2020 23:31   6/27/2019 12:50
# 1973       Open  11/23/2019 15:31   11/23/2019 15:31               NaN
# 1974  Completed    12/2/2018 7:55    2/13/2020 16:55   2/21/2019 11:38
# 1975       Open   10/26/2019 0:12   11/13/2019 12:29               NaN
#
#                 STREET_ADDRESS     CITY  ... CREATED_HOUR  \
# 0            9500 S Kedzie AVE      NaN  ...           15
# 1                          NaN      NaN  ...            8
# 2             109 W MADISON ST  CHICAGO  ...            9
# 3             7900 S PERRY AVE  CHICAGO  ...            8
# 4          1651 W ROOSEVELT RD  CHICAGO  ...           21
# ...                        ...      ...  ...          ...
# 1971        9952 S WESTERN AVE  CHICAGO  ...           19
# 1972        3748 W DIVISION ST      NaN  ...            9
# 1973      2445 N WASHTENAW AVE      NaN  ...           15
# 1974            1456 E 53RD ST  CHICAGO  ...            7
# 1975  5048 S COTTAGE GROVE AVE      NaN  ...            0
#
#       CREATED_DAY_OF_WEEK  CREATED_MONTH X_COORDINATE Y_COORDINATE   LATITUDE  \
# 0                       5             12          NaN          NaN        NaN
# 1                       4             12          NaN          NaN        NaN
# 2                       6              9  1175449.109  1900353.864  41.881956
# 3                       6              9  1176908.775  1852545.439  41.750732
# 4                       5              9  1165345.566  1894764.934  41.866840
# ...                   ...            ...          ...          ...        ...
# 1971                    7             12  1162133.726  1838363.023  41.712126
# 1972                    7              4  1150969.895  1907787.038  41.902867
# 1973                    7             11  1158034.988  1916360.138  41.926251
# 1974                    1             12  1187055.757  1870478.038  41.799698
# 1975                    7             10  1182434.976  1871504.175  41.802631
#
#       LONGITUDE                                  LOCATION COMPLAINT_DATE  \
# 0           NaN                                       NaN     12/20/2018
# 1           NaN                                       NaN     12/19/2018
# 2    -87.631215  (41.881955643397106, -87.63121511544936)      9/28/2018
# 3    -87.627298   (41.75073223780356, -87.62729770130572)      9/28/2018
# 4    -87.668474  (41.866839982710786, -87.66847398368179)      9/27/2018
# ...         ...                                       ...            ...
# 1971 -87.681828               (41.71212555, -87.68182832)      12/1/2018
# 1972 -87.720908   (41.90286742453662, -87.72090790745081)      4/20/2019
# 1973 -87.694722  (41.926251350108245, -87.69472193292415)     11/23/2019
# 1974 -87.589542                   (41.799698, -87.589542)      12/2/2018
# 1975 -87.606460   (41.80263058493142, -87.60646001940721)     10/26/2019
#
#      COMPLAINT_TIME
# 0             15:06
# 1              8:03
# 2              9:27
# 3              8:01
# 4             21:31
# ...             ...
# 1971          19:38
# 1972           9:24
# 1973          15:31
# 1974           7:55
# 1975           0:12
#
# [1976 rows x 39 columns]

# %%
#sort values by date
request_data["COMPLAINT_DATE"] = pd.to_datetime(request_data.COMPLAINT_DATE)
complaints = request_data.sort_values('COMPLAINT_DATE')

# %%
#remove columns we will not use 
restuarant_complaints = complaints[["COMPLAINT_DATE","COMPLAINT_TIME", "STATUS", "CLOSED_DATE", "LOCATION", "ZIP_CODE", "LATITUDE", "LONGITUDE"]]

# %%
request_data2.rename(columns = {"Location": "LOCATION"})
# Out:
#         Inspection ID                     DBA Name  \
# 0             2177022       CORNERSTONE CHILD CARE
# 1             1561742                      LE CAFE
# 2             2288609  LITTLE PEOPLE LEARNING, INC
# 3              335329                   J & J FISH
# 4             1389412                ROYAL CHICKEN
# ...               ...                          ...
# 208249        2078722                         CRIO
# 208250        2288668       ORIGINAL PANCAKE HOUSE
# 208251        2059313  SUBWAY SANDWICHES AND SALAD
# 208252        1497846                RESIDENCE INN
# 208253        1369996                    ST. AILBE
#
#                            AKA Name  License #  \
# 0            CORNERSTONE CHILD CARE  2215716.0
# 1                           LE CAFE  2178017.0
# 2       LITTLE PEOPLE LEARNING, INC  2570234.0
# 3                        J & J FISH    69148.0
# 4                               NaN  2289533.0
# ...                             ...        ...
# 208249                         CRIO    11583.0
# 208250       ORIGINAL PANCAKE HOUSE  2522453.0
# 208251                       SUBWAY  2108309.0
# 208252                RESIDENCE INN  1869250.0
# 208253                    ST. AILBE  2255639.0
#
#                           Facility Type             Risk  \
# 0       Daycare Above and Under 2 Years    Risk 1 (High)
# 1                            Restaurant    Risk 1 (High)
# 2          Children's Services Facility    Risk 1 (High)
# 3                            Restaurant  Risk 2 (Medium)
# 4                            Restaurant  Risk 2 (Medium)
# ...                                 ...              ...
# 208249                       Restaurant    Risk 1 (High)
# 208250                       Restaurant    Risk 1 (High)
# 208251                       Restaurant    Risk 1 (High)
# 208252                       Restaurant  Risk 2 (Medium)
# 208253                           School  Risk 2 (Medium)
#
#                          Address     City State      Zip Inspection Date  \
# 0                1111 N WELLS ST  CHICAGO    IL  60610.0        6/8/2018
# 1             4655 N LINCOLN AVE  CHICAGO    IL  60625.0       7/31/2015
# 2            5650 S WOODLAWN AVE  CHICAGO    IL  60637.0       5/10/2019
# 3                 1945 E 79TH ST  CHICAGO    IL  60649.0       10/7/2010
# 4             5254 W CHICAGO AVE  CHICAGO    IL  60651.0        4/9/2014
# ...                          ...      ...   ...      ...             ...
# 208249  2506-2508 N CLYBOURN AVE  CHICAGO    IL  60614.0       8/21/2017
# 208250       616 W DIVERSEY PKWY  CHICAGO    IL  60614.0       5/13/2019
# 208251          3946 W CERMAK RD  CHICAGO    IL  60623.0       5/30/2017
# 208252         410 N DEARBORN ST  CHICAGO    IL  60654.0      10/15/2014
# 208253             9037 S HARPER  CHICAGO    IL  60619.0      10/28/2013
#
#               Inspection Type             Results  \
# 0                     Canvass                Pass
# 1           Recent Inspection  Pass w/ Conditions
# 2                     Canvass  Pass w/ Conditions
# 3                     Canvass                Pass
# 4       License Re-Inspection                Pass
# ...                       ...                 ...
# 208249                Canvass            No Entry
# 208250                Canvass  Pass w/ Conditions
# 208251                Canvass                Pass
# 208252                Canvass                Pass
# 208253                Canvass                Fail
#
#                                                Violations   Latitude  \
# 0       32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.902439
# 1       21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  41.966413
# 2       3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.791762
# 3       32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.751489
# 4                                                     NaN  41.895023
# ...                                                   ...        ...
# 208249                                                NaN  41.926985
# 208250  9. NO BARE HAND CONTACT WITH RTE FOOD OR A PRE...  41.932916
# 208251  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.851667
# 208252  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.889634
# 208253  21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  41.730308
#
#         Longitude                                  LOCATION
# 0      -87.634278   (41.90243867998565, -87.63427774207456)
# 1      -87.686937   (41.96641308847062, -87.68693718914149)
# 2      -87.596612  (41.791761831643065, -87.59661166762221)
# 3      -87.576634   (41.75148901882857, -87.57663364715819)
# 4      -87.757835   (41.89502331496054, -87.75783480830066)
# ...           ...                                       ...
# 208249 -87.672103   (41.92698538037725, -87.67210268081504)
# 208250 -87.644604   (41.93291622396691, -87.64460350952312)
# 208251 -87.724087   (41.85166707002555, -87.72408696416231)
# 208252 -87.629744   (41.88963425287828, -87.62974429986244)
# 208253 -87.586630   (41.73030761689423, -87.58662986418797)
#
# [208254 rows x 17 columns]

# %%
#separate complaint code from comments
for row in request_data2:
    try:
        request_data2[['Violation_Code', 'Violation_Comment']]= request_data2.Violations.str.split("- Comments:", expand = True,)
    except ValueError:
        print("empty value")
# Out:
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value
# empty value

# %%
request_data2.head()
# Out:
#    Inspection ID                     DBA Name                     AKA Name  \
# 0        2177022       CORNERSTONE CHILD CARE       CORNERSTONE CHILD CARE
# 1        1561742                      LE CAFE                      LE CAFE
# 2        2288609  LITTLE PEOPLE LEARNING, INC  LITTLE PEOPLE LEARNING, INC
# 3         335329                   J & J FISH                   J & J FISH
# 4        1389412                ROYAL CHICKEN                          NaN
#
#    License #                    Facility Type             Risk  \
# 0  2215716.0  Daycare Above and Under 2 Years    Risk 1 (High)
# 1  2178017.0                       Restaurant    Risk 1 (High)
# 2  2570234.0     Children's Services Facility    Risk 1 (High)
# 3    69148.0                       Restaurant  Risk 2 (Medium)
# 4  2289533.0                       Restaurant  Risk 2 (Medium)
#
#                Address     City State      Zip Inspection Date  \
# 0      1111 N WELLS ST  CHICAGO    IL  60610.0        6/8/2018
# 1   4655 N LINCOLN AVE  CHICAGO    IL  60625.0       7/31/2015
# 2  5650 S WOODLAWN AVE  CHICAGO    IL  60637.0       5/10/2019
# 3       1945 E 79TH ST  CHICAGO    IL  60649.0       10/7/2010
# 4   5254 W CHICAGO AVE  CHICAGO    IL  60651.0        4/9/2014
#
#          Inspection Type             Results  \
# 0                Canvass                Pass
# 1      Recent Inspection  Pass w/ Conditions
# 2                Canvass  Pass w/ Conditions
# 3                Canvass                Pass
# 4  License Re-Inspection                Pass
#
#                                           Violations   Latitude  Longitude  \
# 0  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.902439 -87.634278
# 1  21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  41.966413 -87.686937
# 2  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.791762 -87.596612
# 3  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.751489 -87.576634
# 4                                                NaN  41.895023 -87.757835
#
#                                    Location  \
# 0   (41.90243867998565, -87.63427774207456)
# 1   (41.96641308847062, -87.68693718914149)
# 2  (41.791761831643065, -87.59661166762221)
# 3   (41.75148901882857, -87.57663364715819)
# 4   (41.89502331496054, -87.75783480830066)
#
#                                       Violation_Code Violation_Comment
# 0  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...              None
# 1  21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...              None
# 2  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...              None
# 3  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...              None
# 4                                                NaN               NaN

# %%
inspect_complaints = pd.merge(request_data2, restuarant_complaints, on = "LOCATION", how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-58f64d008185> in <module>
# ----> 1 inspect_complaints = pd.merge(request_data2, restuarant_complaints, on = "LOCATION", how = 'inner')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     994                         right_keys.append(rk)
#     995                     if lk is not None:
# --> 996                         left_keys.append(left._get_label_or_level_values(lk))
#     997                         join_names.append(lk)
#     998                     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'LOCATION'
